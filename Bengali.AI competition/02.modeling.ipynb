# %%
cd /content/drive/My Drive/kaggle/Bengali.AI competition
# Out:
# [Errno 2] No such file or directory: '/content/drive/My Drive/kaggle/Bengali.AI competition'
# /content

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
import torch
import torch.nn as nn

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Pretrainedmodel

# %%
# !pip install pretrainedmodels
# pytorch를 이용하여 pretrainedmodel들을 불러온다
import pretrainedmodels
# Out:
# ...
#      |████████████████████████████████| 61kB 2.1MB/s
# ...
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-cp36-none-any.whl size=60962 sha256=6ebf39bbff99f3dd8368572ab28c5437928a99173aae774a12585ff9d40b9b7a
#   Stored in directory: /root/.cache/pip/wheels/69/df/63/62583c096289713f22db605aa2334de5b591d59861a02c2ecd
# Successfully built pretrainedmodels
# ...

# %%
# resnet 사용
model_name = 'resnet34'
backbone = pretrainedmodels.__dict__[model_name](pretrained='imagenet')
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# ...

# %%
backbone
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
print(backbone.conv1)
print(backbone.last_linear)
# Out:
# Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
# Linear(in_features=512, out_features=1000, bias=True)

# %% [markdown]
# pretrained model은 input과 ouput이 우리의 dim과 다르기 때문에 처음과 마지막 layer를 수정해야한다.

# %%
backbone.conv1 = nn.Conv2d(1,64,7,2,3) # 우리의 data는 1 channel이니까!
backbone.last_linear.out_features = 186

print(backbone.conv1)
print(backbone.last_linear)
# Out:
# Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
# Linear(in_features=512, out_features=186, bias=True)
